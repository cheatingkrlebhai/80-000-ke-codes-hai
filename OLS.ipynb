# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as sm
import statsmodels.api as sm

# %%
df = pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
x = df.drop(['variety','sepal.length', ],axis=1)
y = df['sepal.length']

ols = sm.OLS(y,x).fit()

# %%
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:           sepal.length   R-squared (uncentered):                   0.996
# Model:                            OLS   Adj. R-squared (uncentered):              0.996
# Method:                 Least Squares   F-statistic:                          1.284e+04
# Date:                Sat, 16 Dec 2023   Prob (F-statistic):                   1.33e-177
# Time:                        12:05:40   Log-Likelihood:                         -61.215
# No. Observations:                 150   AIC:                                      128.4
# Df Residuals:                     147   BIC:                                      137.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...
